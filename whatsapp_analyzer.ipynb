# %% [markdown]
# # Práctica Logs
# + Autor: Felipe David Navarro Pecci

# %% [markdown]
# ## 1) Añado el archivo con stopwords para español

# %%
import io
import sys

    
def replace_bad_character(line):
    return line.strip().replace(u"\u202a", "").replace(u"\u200e", "").replace(u"\u202c", "").replace(u"\xa0", " ")

try: 
    filepath = raw_input("Please input the chat filepath:")
except NameError:
    filepath = input("Please input chat filepath:")

try:
    with io.open(filepath, "r", encoding="utf-8") as file:
        content = [replace_bad_character(l) for l in file.readlines()]
    
except IOError as e:
    print("File \"" + filepath + "\" not found. Please recheck your file location")
    sys.exit()

common_words = []
cw_filepath = ""

cw_option = "Please select common word file or leave it blank to escape: \n\
    1: Indonesian (id_cw.py)\n\
    2: English (en_cw.py)\n\
    3: Spanish\n\
    4: Custom file\n\
    5: Skip common word\n"
try: 
    cw = raw_input(cw_option)
except NameError:
    cw = input(cw_option)
    
if cw == "1":
    cw_filepath = "id_cw"
elif cw == "2":
    cw_filepath = "en_cw"
elif cw == "3":
    cw_filepath = "es_cw"
elif cw == "4":
    """
    Prompt user to input the file path
    """
    try: 
        cw_filepath = raw_input("Please input your common word filepath")
    except NameError:
        cw_filepath = input("Please input your common word filepath")

if len(cw_filepath) > 0:

    try:
        common_words = __import__(cw_filepath, globals(), locals(), [common_words]).common_words
        
    except:
        print("Error getting common word file location")
        sys.exit()
else:
    print("You skipped common word.")

try: 
    verbose = raw_input("You wanna print the verbose mode? y/[N]: ") == "y" or False
except NameError:
    verbose = input("You wanna print the verbose mode? y/[N]: ") == "y" or False
# Out:
# Please input chat filepath: C:\Users\fdnav\mbd_logs\Chat de WhatsApp con Master MBD.txt
# Please select common word file or leave it blank to escape:
#     1: Indonesian (id_cw.py)
#     2: English (en_cw.py)
#     3: Spanish
#     4: Custom file
#     5: Skip common word
#  3
# You wanna print the verbose mode? y/[N]:  n

# %%
import re
import errno
import pandas as pd
import emoji
from collections import Counter
from dateutil import parser
import operator
import numpy as np
import matplotlib.ticker as ticker
import matplotlib.cm as cm
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
# %matplotlib inline


class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
"""
Global vars
"""
chat_df = pd.DataFrame(index=None,columns=["msg_timestamp","author","msg_body"])

chat_of_members = {}
member_chat = {"member": [], "chat_count": []}
attachments = {}
refered_web = {"domain": [], "d_count": []}
popular_words = {}
chat_words = ""
emojis = {"emj_char": [], "char_count": []}
heat_map = {
    "day": [], 
    "hour": [], 
    "chat_count": []
}
deleted_message = 0
pure_chat = ""
total_chat = 0

"""
Starting line mean a line that started with date time.
Because there are multiline chat. I called it following line.
A starting line must be classified before it's data being extracted.
"""
def is_starting_line(line):
    pattern = r"""
        (\[?)       #Zero or one open square bracket '['
        (((\d{1,2})   #1 to 2 digit date
        (/|-)       #'/' or '-' separator
        (\d{1,2})   #1 to 2 digit month
        (/|-)       #'/' or '-' separator
        (\d{2,4}))   #2 to 4 digit of year
        (,?\s)      #Zero or one comma ',' and ingle space
        ((\d{1,2})  #1 to 2 digit of hour
        (:|\.)      #Colon ':' or dot '.' separator
        (\d{2})     #2 digit of minute
        (\.|:)?     #Zero or one of dot '.' or colon ':'
        (\d{2})?    #Zero or one of 2 digits of second
        (\s[AP]M)?))  #Zero or one of ('space', 'A' or 'P', and 'M'
        (\]?\s-?\s?\s?)#Zero or one close square bracket ']', Zero or one (space and '-'), zero or one space
        (.+)        #One or more character of chat member phone number or contact name
    """
    
    return re.match(re.compile(pattern, re.VERBOSE), line)

"""
"Is Chat" means the body of a line is not an event.
May contains attachment
"""
def is_chat(body):
    pattern = r"""
            ([^:]+)#Chat member
            (:)   #Colon separator
            (.+)  #One or more charachter of message content
    """
    
    return re.match(re.compile(pattern, re.VERBOSE), body)

"""
Classify attachment
Note: in Android, there is no proper description wether it's a image, 
      video, audio, gif, or sticker.
"""
def contains_attachment(body):
    pattern_attachment = [
        ".*<Media omitted>$", #English version of android attachment
        ".*<Media tidak disertakan>$", #Indonesia version of android attachment
        ".*Pesan tidak didukung$", #Some device not recognize sticker attachment
        ".+\.vcf \(file\sterlampir\)$", #Indonesian version of android contact card,
        ".+\.vcf \(file\sattached\)$", #Indonesian version of android contact card,
        ".*image omitted$",
        ".*video omitted$",
        ".*document omitted$",
        ".*Contact card omitted$",
        ".*audio omitted$",
        ".*GIF omitted$",
        ".*sticker omitted$"
    ]
    
    for p in pattern_attachment:
        match = re.match(p, body)
        if match:
            return body
    return None

"""
Event means logs of chat activity e.g member left, member added, removed, etc.
This kind of line can not count as a chat
"""
def is_event(body):
    pattern_event = [
        "Messages to this group are now secured with end-to-end encryption\.$",
        ".+\screated this group$",
        ".+\skeluar$",
        ".+\sleft$",
        ".+\stelah bergabung menggunakan tautan undangan grup ini$",
        ".+\smenambahkan\s.+",
        ".+\sadded\s.+",
        ".+\sremoved\s.+",
        ".*You joined using this group's invite links$",
        ".+'s security code changed\.$",
        ".*telah mengganti nomor teleponnya ke nomor baru. Ketuk untuk mengirim pesan atau menambahkan nomor baru\.$",
        ".*changed their phone number to a new number. Tap to message or add the new number\.$"
    ]
    
    for p in pattern_event:
        match = re.match(p, body)
        if match:
            return match
    return None
"""
Deleted message
"""
def is_deleted(body):
    p = [
        ".*This message was deleted\.$",
        ".*Pesan ini telah dihapus$"
    ]
    
    for p in p:
        match = re.match(p, body)
        if match:
            return body
    return None

"""
EXTRACT TIMESTAMP
"""
def extract_timestamp(time_string):
    return parser.parse(time_string)

"""
Check if chat contais a url
"""
def extract_url(body):
    pattern = "https?://(?:[-\w.]|(?:%[\da-fA-F]{2}))+"
    
    return re.findall(pattern, body)

def get_domain(str):
    domain = str.replace("http://", '')
    domain = domain.replace("https://", '')
    domain = domain.split("/")
    return domain[0]

"""
EMOJI
"""
def extract_emojis(string):
    emj = []
    for c in string:
        if c in emoji.UNICODE_EMOJI:
            emj.append(c)

    if len(emj) > 0:
        increment_emoji_count(emj)
    
    return emj

"""
Count top words
"""
def get_words(msg):
    
    #remove non alpha content
    regex = re.sub(r"[^a-z\s]+", "", msg.lower())
    regex = re.sub(r'[^\x00-\x7f]',r'', regex)
    words = regex.split(" ")
    
    for x in words:
        if x:
            rank_word(x)
            
    return words

def rank_word(word):
    
    if not word in common_words:
        popular_words[word] = popular_words.get(word, 0) + 1
        global chat_words
        chat_words += " {0}".format(word)
        
    return word
    
"""
Counting function
"""

"""
Rank the 'Most Active user'
"""        
def increment_chat_count(member):
    member_chat["member"].append(member)
    member_chat["chat_count"].append(1)
    global total_chat
    total_chat += 1
    
    return member
 
def increment_attachment_count(message):
    
    if "image omitted" in message:
        attachments["image"] = attachments.get("image", 0) +1
        return
        
    if "video omitted" in message:
        attachments["video"] = attachments.get("video", 0) +1
        return
    
    if "audio omitted" in message:
        attachments["audio"] = attachments.get("audio", 0) +1
        return
    
    if "document omitted" in message:
        attachments["document"] = attachments.get("document", 0) +1
        return
    
    if "Contact card omitted" in message or ".vcf" in message:
        attachments["contact"] = attachments.get("contact", 0) +1
        return
    
    if "GIF omitted" in message:
        attachments["gif"] = attachments.get("gif", 0) +1
        return
    
    if "sticker omitted" in message:
        attachments["sticker"] = attachments.get("sticker", 0) +1
        return
    
    ##Unknown attachment
    attachments["unknown"] = attachments.get("unknown", 0) +1

    

def increment_link_count(urls):
    for url in urls:
        increment_domain_count(get_domain(url))
                    
    return len(urls)
    
def increment_domain_count(domain):
    refered_web["domain"].append(domain)
    refered_web["d_count"].append(1)

def increment_emoji_count(char_list):
    groups = Counter(char_list)
    for c in groups.items():
        emojis["emj_char"].append(c[0])
        emojis["char_count"].append(c[1])
        
def increment_heatmap(dt):
    heat_map["day"].append(dt.strftime("%A"))
    heat_map["hour"].append(dt.strftime("%H"))
    heat_map["chat_count"].append(1)

def increment_deleted():
    global deleted_message
    deleted_message += 1
"""
Self explained
"""
def parse_line(line, verbose):
    prefix = ""
    is_starting = is_starting_line(line)
    
    if is_starting:
        #Check wether the starting line is a chat or an event
        body = is_starting.group(18)
        chat = is_chat(body)
        dt = extract_timestamp(is_starting.group(2).replace(".", ":"))
        increment_heatmap(dt)
        
        if chat:
            has_attachment = contains_attachment(chat.group(3))
            increment_chat_count(chat.group(1))
            message_body = chat.group(3)
            
            
            if has_attachment:
                prefix = "@@@" 
                increment_attachment_count(has_attachment)
                
                if verbose: print(bcolors.OKBLUE + bcolors.HEADER + prefix + line)
                
            else:
                if is_deleted(message_body):
                    increment_deleted()
                else:
                    prefix = "+++"
                    
                    #URL & Domain
                    urls = extract_url(message_body)
                    if urls:
                        increment_link_count(urls)

                    #Emoji
                    emjs = extract_emojis(message_body)
                    
                    #Word Count & Wordcloud
                    get_words(message_body)
                
                    if verbose: print(bcolors.OKGREEN + bcolors.HEADER + prefix + line)
                
        elif is_event(body):
            prefix = "***"
                
            if verbose: print(bcolors.WARNING + prefix + line)
        
    else:
        prefix = "|||"
        
        #URL & Domain
        urls = extract_url(line)
        if urls:
            increment_link_count(urls)
        
        #Emoji    
        emjs = extract_emojis(line)
        
        #Word Count & Wordcloud
        get_words(line)

        if verbose: print(bcolors.FAIL + prefix + line)
            
            

print("Extracting data. Please wait....")

for line in content:
    parse_line(line, verbose) # Desactivo el verbose para que no me muestre todo el chat por pantalla
    
print("Done. You can run next cell.")
# Out:
# Extracting data. Please wait....
# /usr/libexec/java_home -V
#
# Deberían poder ver la distintas máquinas virtuales de Java que tienen
#
# Este año, en lugar de trabajar con una VPN, accederéis al cluster mediante unos servidores:
#
# Servicios HTTP varios: https://acceso.comillas.edu
# SSH al EDGE: https://aulasvirtuales.comillas.edu
#
# Un saludo,
#
# David
# contraseña:mbd
#
#
#
# Learn more about Teams
#
# Luego con el comando que aparece en el pdf se ejecuta el codigo del archivo codigo.py con spark.
# 23 de octubre
# 27 de octubre
# diciembre
#
# 🟢*Machine Learning* hemos destacado la velocidad de las clases y que asume que toda la clase tiene un conocimiento de R avanzado. Van a intentar hacer las clases más practicas y que vayamos probando nosotros en nuestro ordenador el codigo y que Sonja haga de profesora de apoyo contestando dudas personales.
#
# 🟣*Adquisición y transformación del datos* esta asignatura comienza el 26 de octubre y volverán a hacer desdoble (el horario lo publicaran a lo largo de la semana que viene)
#
# En general, van a intentar hacer desdobles o profesores de apoyo en todas las asignaturas tanto en este cuatrimestre como en el siguiente.
#
# Cada dos semanas nos reuniremos con el coordinador. Os recuerdo que si tenéis cualquier comentario, petición o duda nos lo digáis  tanto por aquí como por privado para intentar darle solución.
# Calle del Conde Duque, 10, 28015 Madrid, España
# +34 915 59 18 94
# https://goo.gl/maps/2URQwQfRUmv4aRyu8
# Fran
# Virginia
# Grupo A
# Virginia Hernández x Manuel
# Jorge Gómez  x  Alejandro Polo
# Grupo A
# Virginia Hernández x Victoria Meseguer
# Jorge Gómez  x  Alejandro Polo
# Edu Lobo
# Vicky
# Lucia
# Mery
# Edu Lobo
# Vicky
# Lucia
# Mery
# Miren
# Edu Lobo
# Vicky
# Lucia
# Mery
# Miren
# Angel
# Edu Lobo
# Manuel
# Lucia
# Mery
# Miren
# Angel
# Edu Lobo
# Manuel
# Lucia
# Mery
# Miren
# Angel
# Sergio
# Edu Lobo
# Manuel
# Angel
# Lucia
# Mery
# Miren
# Sergio
#
# Respecto a la fecha límite del Assignment de clasificación. La fecha límite original era el lunes 26 de octubre.
#
# Nos habéis pedido retrasar esta fecha porque tenéis un examen esta semana. En el pasado hemos tenido muy malas experiencias retrasando la entrega del Assignment, porque perjudica el aprendizaje en el tema de regresión etc.
#
# De todas formas, vamos a intentar ayudaros. Primero, os damos un día más - es decir, la fecha de entrega del Assignment será el martes 27 de octubre. Luego, si no os da tiempo de terminar el Assignment hasta el martes, vamos a permitir también que se entreguen Assignments incompletos (obviamente si faltan cosas, habrá un impacto en la nota del Assignment).
#
# Si queréis entregar tarde, vamos a permitirlo también esta vez (de forma excepcional), pero hay una penalización en la nota (un 10% de penalización por día de retraso).
#
# Después de la clase del jueves (donde comentaremos el MLP) en un principio ya tendréis todas las herramientas para completar vuestro Assignment. Obviamente si queréis entregar temprano y quitároslo de encima, se puede hacer también.
#
# Mucho ánimo y nos vemos en clase.
# Un saludo,
# Sonja & José
#
# Espero que os encontréis bien. El  motivo de este correo es saber si hay algún caso positivo de COVID en el MBD para seguir protocolo establecido. Por favor es un tema muy importante para la salud de todos, por lo que os ruego si hay algún caso POSITIVO  que se ponga en contacto conmigo de manera urgente
#
#
#
#
#
# Un abrazo a todos
# 2 María
# 3 Andrés
# 4 Ignacio
# 5 ander
# 6 vicky
# 2 María
# 3 Andrés
# 4 Ignacio
# 5 ander
# 6 vicky
# 7 Álvaro
# 2 María
# 3 Andrés
# 4 Ignacio
# 5 ander
# 6 vicky
# 7 Álvaro
# 8 Corina
# 2 María
# 3 Andrés
# 4 Ignacio
# 5 ander
# 6 vicky
# 7 Álvaro
# 8 Corina
# 9 Raúl
# 2 María
# 3 Andrés
# 4 Ignacio
# 5 ander
# 6 vicky
# 7 Álvaro
# 8 Corina
# 9 Raúl
# 10 Manuel
# 2 María
# 3 Andrés
# 4 Ignacio
# 5 ander
# 6 vicky
# 7 Álvaro
# 8 Corina
# 9 Raúl
# 10 Manuel
# 11 María J.
# 2 María
# 3 Andrés
# 4 Ignacio
# 5 ander
# 6 vicky
# 7 Álvaro
# 8 Corina
# 9 Raúl
# 10 Manuel
# 11 María J.
# 12 Nacho
# 2 María
# 3 Andrés
# 4 Ignacio
# 5 ander
# 6 vicky
# 7 Álvaro
# 8 Corina
# 9 Raúl
# 10 Manuel
# 11 María J.
# 12 Nacho
# 13 Jacobo
#
# Te escribo para informarte sobre como marcha el proceso de corrección de vuestros exámenes, porque me imagino que algunos de vosotros podéis estar inquietos sin tener noticias de mi desde hace días.
#
# Me gustaría pedirte que transmitieras a la gente de clase que estoy trabajando todo lo rápido que puedo para que tengáis esas notas lo antes posible. Pero la corrección está siendo bastante laboriosa (desde hace varios días, y desde luego toda esta semana, apenas hago otra cosa por las tardes que corregir vuestros exámenes). Y no he querido adelantar resultados hasta poder daros las notas a todos a la vez.
#
# Pero al ritmo al que avanzo ya tengo claro que salvo imprevistos las notas del examen estarán listas mañana al final de la tarde, así que solo os pido un poco de paciencia más.
#
# Gracias y saludos.
#
# sintiéndolo mucho, no he conseguido ningún hueco compatible con cambiar la clase de Casos de negocio del viernes 13 de noviembre (el 11 no puede ser por una optativa por lo visto), por lo que el viernes 13 no habrá clase de casos de negocio y la recuperaremos más adelante, quizás aprovechando con algún ponente que no pueda el viernes.
#
# Disculpar las molestias,
#
# Un saludo
# Machine learning: lunes 14
# Tecnologia: jueves 17
# Adquisicion: lunes 21
# Nos lo envían compañeros de promociones anteriores que ahora trabajan en Google y animan a los ICAI a asistir.
#
# El próximo 26 de Noviembre de 2020 hay un evento online de promoción de Google. Entiendo que fundamentalmente estará orientado a contratación de alumnos de nivel master, pero también me han comentado que están organizando ahora las becas de prácticas para verano y eso puede interesar casi a todos.
#
# En este enlace proporcionamos más detalles sobre el evento: https://events.withgoogle.com/road-to-google-2020/
#
# RAFAEL
#
# De cara a preparar el examen final, nos preguntábamos si nos podías indicar algo de la estructura de este como:
#
# ¿Hay preguntas teóricas y prácticas ?
# En caso de que sí, ¿cuántos puntos corresponden a cada parte?
# ¿Se puede llevar apuntes al examen?
#
# Y por último, ¿seria posible subir el examen final del año pasado para practicar?
#
# Muchas gracias,
#
# Victoria
#
# De cara a preparar el examen final, nos preguntábamos si nos podías indicar algo de la estructura de este como:
#
# 1 ¿Hay preguntas teóricas y prácticas ?
# 2 En caso de que sí, ¿cuántos puntos corresponden a cada parte?
# 3 ¿Se puede llevar apuntes al examen?
# 4 ¿Es necesario aprobar tanto tu parte como la de Jorge para aprobar la asignatura?
#
# Y por último, ¿seria posible subir el examen final del año pasado para practicar?
#
# Muchas gracias,
#
# Victoria
# el grupo a: viernes
#
# 1. Sí, un test teórico y una parte práctica.
# 2.Depende de cada año pero siempre la parte práctica ha tenido más puntos que la teórica.
# 3.La teoría es sin apuntes y se hace al comienzo del examen. Para el resto del examen podréis usar todo lo que necesitéis .
# 4. Habría que ver el caso en concreto , en principio no es necesario aprobar las dos partes en el examen .
# 5.No compartimos exámenes de otros años. Es muy similar a las propuestas de ejercicios de clase.
#
# Un saludo!
#
# PAtricia
#
# * Fran Rodríguez
#
# * Fran Rodríguez
# Virginia Hernández
#
# * Fran Rodríguez
# Virginia Hernández
# Andrés (?)
# Alvaro otaduy
#
# * Fran Rodríguez
# Virginia Hernández
# Andrés (?)
# Alvaro otaduy
# Alejandro Polo
#
# * Fran Rodríguez
# Virginia Hernández
# Andrés (?)
# Alvaro otaduy
# Alejandro Polo
# Álvaro Fortún
#
# * Fran Rodríguez
# Virginia Hernández
# Andrés (?)
# Alvaro otaduy
# Alejandro Polo
# Álvaro Fortún
# Maria Garcia
#
# * Fran Rodríguez
# Virginia Hernández
# Andrés
# Alvaro otaduy
# Alejandro Polo
# Álvaro Fortún
# Maria Garcia
#
# * Fran Rodríguez
# Virginia Hernández
# Andrés
# Alvaro otaduy
# Alejandro Polo
# Álvaro Fortún
# Maria Garcia
# Eduardo Lobo
# Lunes y martes empezar a las 15:20 y no hacer descanso
#
# ⭕️ *CAMBIO 2*
# Cambiar Trabajo de Fin de Máster al martes de 17h a 19h
# Es decir, el martes tendríamos clase de 3 a 7 y los miércoles de 5 a 9
#
#
#
# Hemos compartido el mensaje con la clase y el sentimiento de decepción es generalizado. Ya fuera del papel de alumnos, como clientes que hacemos una fuerte inversión en este programa esperamos una comunicación más transparente y flexible en aspectos tan importantes como este.
#
#
#
# Con los mensajes que hemos recibido ayer y hoy no tenemos ningún tipo de detalle de cuál es el motivo de que estos cambios no sean viables. Incluso este último que parecía factible, ahora no lo es pero no recibimos mayor explicación que trasladar al resto de compañeros afectados.
#
#
#
# No dudamos del esfuerzo considerable que implica esta reorganización pero dar el asunto por cerrado tras pasar ni tan siquiera 24 horas no nos parece razonable tampoco. Pedimos por favor reconsiderar algunas de las opciones comentadas ayer o bien alguna de las alternativas que se nos ocurren:
#
# • Buscar un desdoble con un profesor que no tenga la limitación horaria de tener que dar la clase a las 15h como nos sucede lunes, martes y miércoles con Luis.
#
# • Flexibilidad por parte de los profesores cuyas clases empiezan en la primera franja horaria con que los alumnos que no pueden asistir a la clase de las 15h puedan conectarse por Teams exclusivamente a estas horas. Si fuera necesario        podríamos incluso censar el listado de estos alumnos específicos.
#
#
#
# Queremos llegar a una solución para que los alumnos que tienen una mayor carga laboral puedan compatibilizar ambas situaciones como hicimos en el primer cuatrimestre, ya que de lo contrario hay clases a las que algunos compañeros no van a poder asistir de forma sistemática.
#
#
#
# Gracias de nuevo,
#
# Un saludo
# Gracias!
# -Las clases de las 3 empezaremos a las 3 y media
# -Los alumnos de la lista podrán asistir online y ademas las clases serán grabadas
# -A la clase del TFM empieza a las 4 y ademas habrá que asistir los primero días cuando expliquen la documentación y lo que hay que hacer pero luego a las presentaciones no será obligatorio asistir
#
# * Fran Rodríguez
# Virginia Hernández
# Andrés
# Alvaro otaduy
# Alejandro Polo
# Álvaro Fortún
# Maria Garcia
# Eduardo Lobo
# ¿La clase de TFM también retrasaría una hora las posteriores?
# Para las presentaciones de tfm se seguimiento hay que ir a la clase entera o solo a la hora que te han convocado?
# Done. You can run next cell.

# %%
"""
DataFrame
"""
chat_per_member = (pd.DataFrame(member_chat)
                     .groupby(["member"])
                     .sum()
                     .sort_values(by = ['chat_count'], ascending=False))
popular_words_df = sorted(popular_words.items(), key=operator.itemgetter(1), reverse=True)
domains = (pd.DataFrame(refered_web)
                     .groupby(["domain"])
                     .sum()
                     .sort_values(by = ['d_count'], ascending=False))
emojis_df = (pd.DataFrame(emojis)
                     .groupby(["emj_char"])
                     .sum()
                     .sort_values(by = ['char_count'], ascending=False))
top_repeated_emoji = (pd.DataFrame(emojis)
                     .sort_values(by = ['char_count'], ascending=False))
heatmap_df = pd.DataFrame(heat_map)
grouped_heatmap = heatmap_df.groupby(["day", "hour"]).sum().sort_values(by=["chat_count"], ascending=False)
pivoted_heatmap = pd.pivot_table(grouped_heatmap, values='chat_count', index=['day'], columns=['hour'])

print("Done. You can run next cell.")
# Out:
# Done. You can run next cell.

# %% [markdown]
# ## Guardando los chats en raw
#
# + Parseo cada línea y veo si es un chat
# + Si es un chat guardo en un Dataframe: timestamp, autor, mensaje(raw)

# %%
# Out:
# {}

# %%
chat_per_member.head()
# Out:
#                         chat_count
# member
# Vicky MBD                      578
# Fran MASTER BD                 113
# Andrés Jiménez                 104
# Virginia Hernández MBD          97
# Lidia Sanz                      83

# %%
popular_words_df[0:10]
# Out:
# [('si', 196),
#  ('gracias', 117),
#  ('clase', 98),
#  ('examen', 86),
#  ('multimedia', 69),
#  ('omitido', 69),
#  ('alguien', 56),
#  ('grupo', 53),
#  ('horario', 45),
#  ('b', 44)]

# %%
domains.head()
# Out:
#                              d_count
# domain
# forms.gle                          8
# teams.microsoft.com                3
# acceso.comillas.edu                2
# aulasvirtuales.comillas.edu        1
# collabedit.com                     1

# %%
"""
Top Member Chat
"""
top_member = chat_per_member.head(20)
if not top_member.empty:
    sns.set()
    member_plot = top_member.plot(kind='bar', legend=None, title="Top 20 active member", figsize=(18, 6), color="purple")
    member_plot.set_xlabel("Member (phone number/contact name)")
    member_plot.set_ylabel("Chat Count")
    for i, v in enumerate(top_member["chat_count"]):
        member_plot.text(i - .15, v + 3, v, color="#004d40")
else:
    print("This chat has no member")

# %%
"""
Heatmap
"""
heatmap_df = pd.DataFrame(heat_map)
if not heatmap_df.empty:
    grouped_heatmap = heatmap_df.groupby(["day", "hour"]).sum().sort_values(by=["chat_count"], ascending=False)
    pivoted_heatmap = pd.pivot_table(grouped_heatmap, values='chat_count', index=['day'], columns=['hour'])
    plt.figure(figsize = (16,5))
    sns.heatmap(pivoted_heatmap, 
                annot=True, 
                fmt=".0f", 
                linewidths=.2,
                cmap="YlGnBu",
                cbar=False
               )
else:
    print("This chat does not contain any datetime")

# %%
s_attachments = sorted(attachments.items(), key = operator.itemgetter(1), reverse=True)
if s_attachments:
    at_labels = [x[0].title() + " " + str(x[1]) for x in s_attachments]

    at_explode = tuple([0 + i * 0.1 for i in range(len(s_attachments))])
    at_sizes = [x[1] for x in s_attachments]
    at_colors = ["#FF6D00", "#64DD17", "#00B8D4", "#304FFE", "#AA00FF", "#d50000", "#546E7A", "#dddddd"]
    at_pie = plt.pie(at_sizes,  
             autopct='%1.1f%%',
             explode=at_explode,
             pctdistance=1.2,
             colors=at_colors,
             startangle=160,
             radius=1.3,
             wedgeprops = { 'linewidth' : 2, 'edgecolor' : 'white' },
    )

    at_centre_circle = plt.Circle((0,0),0.85,color='white', fc='white',linewidth=1.25)
    at_fig = plt.gcf()
    at_fig.gca().add_artist(at_centre_circle)

    plt.legend(
        loc='upper left',
        labels=at_labels,
        prop={'size': 11},
        bbox_to_anchor=(1, 1)
    )
    at_axis = plt.axis('equal')
else:
    print("This chat contains no attachment.")
# Out:
# This chat contains no attachment.

# %%
"""
Top Website
"""
top_web = domains.head(20).sort_values("d_count")
if not top_web.empty:
    mpl.rc('font', **{'sans-serif' : 'arial', 'family' : 'sans-serif'})
    web_plot = top_web.plot(kind='barh', legend=None, title="Top 20 mentioned domain", figsize=(20,10), color="#1de9b6")
    web_plot.set_xlabel("Mention Count")
    for i, v in enumerate(top_web["d_count"]):
        web_plot.text(1, i - .15, v, color="purple")
else:
    print("This chat not contains any link")

# %%
"""
Wordcloud
"""
if chat_words:
    wordcloud = WordCloud(
        width = 1000, 
        height = 500,
        background_color = "white"
    ).generate(chat_words)

    plt.figure(figsize=(15,8))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()
else:
    print("This chat contains no word")

# %%
"""
Raw Output
"""
print("\n=======================================\n")
print("#Total Chat: {0}".format(total_chat))
print("#Deleted Message: {0}".format(deleted_message))
print("#Total Attachment: {0}".format(sum([x[1] for x in s_attachments])))
for a in s_attachments:
    print("  - : {0}".format(a))
    


print("\n#Top 20 Member")
print("-----------------")
print(top_member)


print("\n#Top 20 Words")
print("-----------------")
for k, v in enumerate(popular_words_df):
    if k < 20:
        print(v)
    else:
        break
        
print("\n#Top 20 Emoji")
print("-----------------")
print(emojis_df.head(20))

print("\n#Top 20 Mentioned Website")
print("-----------------")
print(top_web.sort_values("d_count", ascending=False))
# Out:
# =======================================
#
# #Total Chat: 1682
# #Deleted Message: 0
# #Total Attachment: 0
#
# #Top 20 Member
# -----------------
#                         chat_count
# member
# Vicky MBD                      578
# Fran MASTER BD                 113
# Andrés Jiménez                 104
# Virginia Hernández MBD          97
# Lidia Sanz                      83
# Felipe D Navarro                46
# Raúl Gómez Mbd                  45
# Monu MbD                        42
# +34 655 54 65 74                40
# Eladio Jiménez                  40
# Santiago Cebellán               38
# Ángel MBD                       37
# Thomas Bustos                   35
# Laura Lucendo                   31
# Guillermo Valle MBD             28
# Jacobo Azpeitia                 27
# Lucia Poblador                  26
# +34 661 19 72 74                26
# Natalia Gila                    24
# Raquel García Meneses           24
#
# #Top 20 Words
# -----------------
# ('si', 196)
# ('gracias', 117)
# ('clase', 98)
# ('examen', 86)
# ('multimedia', 69)
# ('omitido', 69)
# ('alguien', 56)
# ('grupo', 53)
# ('horario', 45)
# ('b', 44)
# ('creo', 43)
# ('ms', 42)
# ('semana', 41)
# ('vicky', 40)
# ('final', 37)
# ('vale', 36)
# ('est', 35)
# ('tambin', 35)
# ('va', 33)
# ('dos', 33)
#
# #Top 20 Emoji
# -----------------
# Empty DataFrame
# Columns: [char_count]
# Index: []
#
# #Top 20 Mentioned Website
# -----------------
#                                        d_count
# domain
# forms.gle                                    8
# teams.microsoft.com                          3
# acceso.comillas.edu                          2
# aulasvirtuales.comillas.edu                  1
# collabedit.com                               1
# download.respondus.com                       1
# events.withgoogle.com                        1
# goo.gl                                       1
# horarios.comillas.edu                        1
# manager01.bigdata.alumnos.upcont.es          1
# musing-stonebraker-3eeaa5.netlify.app        1
# repositorio.comillas.edu                     1
# upcomillas-my.sharepoint.com                 1
# www.icai.comillas.edu                        1
# www.youtube.com                              1

# %% [markdown]
# ## Parseo personalizado de los datos
#
# Partiendo del código proporcionado, se modifica para obtener los datos en un dataframe con los siguientes campos:
#
# + msg_timestamp: Timestamp de cuándo se envió el mensaje
# + author: Autor del mensaje
# + msg_body: Contenido del mensaje

# %%
### Detectar dónde empieza cada línea del chat

"""
Starting line mean a line that started with date time.
Because there are multiline chat. I called it following line.
A starting line must be classified before it's data being extracted.
"""
def is_starting_line(line):
    pattern = r"""
        (\[?)       #Zero or one open square bracket '['
        (((\d{1,2})   #1 to 2 digit date
        (/|-)       #'/' or '-' separator
        (\d{1,2})   #1 to 2 digit month
        (/|-)       #'/' or '-' separator
        (\d{2,4}))   #2 to 4 digit of year
        (,?\s)      #Zero or one comma ',' and ingle space
        ((\d{1,2})  #1 to 2 digit of hour
        (:|\.)      #Colon ':' or dot '.' separator
        (\d{2})     #2 digit of minute
        (\.|:)?     #Zero or one of dot '.' or colon ':'
        (\d{2})?    #Zero or one of 2 digits of second
        (\s[AP]M)?))  #Zero or one of ('space', 'A' or 'P', and 'M'
        (\]?\s-?\s?\s?)#Zero or one close square bracket ']', Zero or one (space and '-'), zero or one space
        (.+)        #One or more character of chat member phone number or contact name
    """
    
    return re.match(re.compile(pattern, re.VERBOSE), line)
    
### Detectar si una línea es un evento o un mensaje
"""
"Is Chat" means the body of a line is not an event.
May contains attachment
"""
def is_chat(body):
    pattern = r"""
            ([^:]+)#Chat member
            (:)   #Colon separator
            (.+)  #One or more charachter of message content
    """
    
    return re.match(re.compile(pattern, re.VERBOSE), body)

### Extraer el timestamp de un mensaje

"""
EXTRACT TIMESTAMP
"""
def extract_timestamp(time_string):
    return parser.parse(time_string)
    
# Extraer URL  
def extract_url(body):
    pattern = "https?://(?:[-\w.]|(?:%[\da-fA-F]{2}))+"
    
    return re.findall(pattern, body)

## Comprobar si hay un adjunto
"""
Classify attachment
Note: in Android, there is no proper description wether it's a image, 
      video, audio, gif, or sticker.
"""
def contains_attachment(body):
    pattern_attachment = [
        ".*<Media omitted>$", #English version of android attachment
        ".*<Media tidak disertakan>$", #Indonesia version of android attachment
        ".*Pesan tidak didukung$", #Some device not recognize sticker attachment
        ".+\.vcf \(file\sterlampir\)$", #Indonesian version of android contact card,
        ".+\.vcf \(file\sattached\)$", #Indonesian version of android contact card,
        ".*image omitted$",
        ".*video omitted$",
        ".*document omitted$",
        ".*Contact card omitted$",
        ".*audio omitted$",
        ".*GIF omitted$",
        ".*sticker omitted$"
    ]
    
    for p in pattern_attachment:
        match = re.match(p, body)
        if match:
            return body
    return None


### Parsear líneas
def parse_line(line,chat_df):
    is_starting = is_starting_line(line)
    
    if is_starting:
        #Check wether the starting line is a chat or an event
        body = is_starting.group(18)
        chat = is_chat(body)
        if chat != None:           
            has_attachment = contains_attachment(chat.group(3))
            message_body = chat.group(3)
            
            if has_attachment:
                
                return pd.DataFrame({"msg_timestamp":[],"author":[],"msg_body":[]})
                
                               
            else:
                if is_deleted(message_body):
                    
                    return pd.DataFrame({"msg_timestamp":[],"author":[],"msg_body":[]})
                else:
                    #URL & Domain
                    urls = extract_url(message_body)
                    if urls:
                        
                         return pd.DataFrame({"msg_timestamp":[],"author":[],"msg_body":[]})
                    
                    else:
                    #Add info to my DataFrame
                        autor = chat.group(1)
                        message_body = chat.group(3)
                        message_timestamp = extract_timestamp(is_starting.group(2).replace(".", ":"))
                        new_df = pd.DataFrame({"msg_timestamp":message_timestamp,"author":autor,"msg_body":message_body},index=[0])
                        return new_df
                    
        else:
            return pd.DataFrame({"msg_timestamp":[],"author":[],"msg_body":[]})
                      
    else:
        #URL & Domain
        urls = extract_url(line)
        if urls:
            return pd.DataFrame({"msg_timestamp":[],"author":[],"msg_body":[]})
        
        
        else:
            autor = chat_df["author"].iloc[-1]
            message_body = line
            message_timestamp = chat_df["msg_timestamp"].iloc[-1]
            new_df = pd.DataFrame({"msg_timestamp":message_timestamp,"author":autor,"msg_body":message_body},index=[0])
            return new_df

# %%
chat_df = pd.DataFrame(index=None,columns=["msg_timestamp","author","msg_body"])

# %%
### Parseo el contenido
for line in content:
    new_entry = parse_line(line,chat_df)
    if new_entry.empty:
        pass
    else:
        chat_df=chat_df.append(new_entry,ignore_index=True)

# %%
chat_df.head()
# Out:
#         msg_timestamp          author  \
# 0 2020-09-17 19:35:00       Vicky MBD
# 1 2020-09-17 19:35:00       Vicky MBD
# 2 2020-09-18 11:16:00  Maria Javierre
# 3 2020-09-18 11:16:00  Maria Javierre
# 4 2020-09-20 13:50:00       Vicky MBD
#
#                                            msg_body
# 0                podeis pasar el link de la clase ?
# 1                                            por fa
# 2   Podéis meter en el grupo a esta chica? Gracias!
# 3      Virginia Hernández MBD.vcf (archivo adjunto)
# 4                                Los que tenéis mac

# %% [markdown]
# ## Wordcloud por mes
#
# ¿Cuáles han sido las palabras más habituales cada mes?

# %% [markdown]
# ## Número de mensajes a lo largo del tiempo
# + Gráfico de líneas con número de mensajes por día
# + Usuarios más activos
# +
